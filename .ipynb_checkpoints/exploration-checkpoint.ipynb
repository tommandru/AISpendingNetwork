# %% [markdown]
# # FISD Covenant Exploration
# Loads the FISD extract produced by `main.py` and explores coverage.

# %%
import sys
from pathlib import Path
import pandas as pd
import os

print("python:", sys.version.split()[0])
print("pandas:", pd.__version__)
# Out:
# python: 3.12.13
# pandas: 2.2.3

# %%
# Notebooks live in notebooks/, data in ../data/
current_path = os.getcwd()

DATA = "..\\data\\fisd_mergedissue_covenants.parquet"
df = pd.read_parquet(DATA)
print(f"{len(df):,} rows, {df.shape[1]} columns")
df.head()
# Out:
# 686,438 rows, 29 columns
#    issue_id  issuer_id issuer_cusip issue_cusip complete_cusip          isin  \
# 0       2.0        3.0       000361         AB1      000361AB1  US000361AB18
# 1       3.0    40263.0       00077D         AB5      00077DAB5  US00077DAB55
# 2       4.0    40263.0       00077D         AF6      00077DAF6  US00077DAF69
# 3       5.0    40263.0       00077T         AA2      00077TAA2  US00077TAA25
# 4       6.0    40263.0       00077T         AB0      00077TAB0  US00077TAB08
#
#   sedol offering_date  offering_amt    maturity  ...  cross_acceleration  \
# 0  <NA>    1993-10-12       50000.0  2003-10-15  ...                   Y
# 1  <NA>    1994-01-07      100000.0  1996-01-12  ...                <NA>
# 2  <NA>    1994-07-27      200000.0  2009-08-01  ...                <NA>
# 3  <NA>    1993-05-20      250000.0  2023-05-15  ...                <NA>
# 4  <NA>    1993-10-13      150000.0  2093-10-15  ...                <NA>
#
# ...

# %%
DATA
# Out:
# 'D:\\dissertation\\notebooks\\data\\fisd_mergedissue_covenants.parquet'
